# %%
type dna
    genes::Array{Int16,1}
    score::Float64
    fitness::Float64
end

function fit(d::dna)
    for i in 1:18
        if d.genes[i]==targetlist[i]
            d.score+=1
        end
    end
end


function cross(a::dna,b::dna)
    child=dna([0 for i in 1:18],0.0,0.0)
    contribution=rand(0:1,18)
    for i in 1:18
        if contribution[i]==0
            child.genes[i]=a.genes[i]
        else
            child.genes[i]=b.genes[i]
        end
    end
    return child
end


phenotype(x) = join([char(i) for i in x.genes],"")

target = "to be or not to be"
targetlist = [int(i) for i in target]
population=[dna(rand(32:128,18),0.0,0.0) for i in 1:400]
mutationrate=0.01

for k in 1:75
    matingpool=dna[]


    for i in population
        fit(i)
        i.fitness=i.score/length(targetlist)
    end


    for i in 1:400
        n=int(population[i].fitness*100)
        for j in 1:n
            push!(matingpool,population[i])
        end
    end
    # f=[i.score for i in population]
    # normalized=[i/sum(f) for i in f]
    # fitn=[i.fitness for i in population]
    # println(phenotype(population[indmax(normalized)]))
    # println(phenotype(population[indmax(fitn)]))


    fitn=[i.fitness for i in population]
    println(phenotype(population[indmax(fitn)]))

    #println(length(matingpool))

    for i in 1:400
        daddy=matingpool[rand(1:length(matingpool))]
        mommy=matingpool[rand(1:length(matingpool))]
        population[i]=cross(daddy,mommy)
    end

end
# Out:
# }6uLGRC(rwPH t$o`u
# j@IL. P(uw{' t$oXu
# QF bf o\)lZ:&(K-rG
#  W1ge oo?_&t LC|X\
# guab. oO Bkt-t"By}
# Â€o bkRo8>lot ]"Bb,
# 6yTb. o.sNdt _o Xe
# t; be do $o:[]o -u
# )e b2 oC $o$[t$wbe
# )o be oCTlP$ tUTbe
# $o be oWguot 7bb;
#  o bs oZ Vot ]obye
# t; bW or -ot 9LRbe
# }o DeOor VoV to ue
# Ko be oM #ot to;bm
# Oo ?e or poV to be
# Oo be o( _ot tK be
# To b. or Yot to ye
# 5o be orgnot to be
# to be orAnot toBbe
# to be orAnot torby
# to be oo aot to be
# to be orgoot to be
# to be or -ot to be
# to be or not to te
# to be or not to\]e
# to be or noF to be
# to be or $ot to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
# to be or not to be
